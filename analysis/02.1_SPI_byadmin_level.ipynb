# %% [markdown]
# # Converting SPI Values to Admin 1 and Admin 2

# %%
# %load_ext jupyter_black
import os
from pathlib import Path
import pandas as pd
import geopandas as gpd
# Out:
#                 <script type="application/javascript" id="jupyter_black">
#                 (function() {
#                     if (window.IPython === undefined) {
#                         return
#                     }
#                     var msg = "WARNING: it looks like you might have loaded " +
#                         "jupyter_black in a non-lab notebook with " +
#                         "`is_lab=True`. Please double check, and if " +
#                         "loading with `%load_ext` please review the README!"
#                     console.log(msg)
#                     alert(msg)
#                 })()
#                 </script>

# %%
data_dir = Path(os.getenv("HAM_DIR")) / "precipitation/"
shp_dir = Path(os.getenv("AA_DATA_DIR")) / "public/raw/ner/cod_ab/ner_cod_ab/"

# %%
ner_shp_adm0 = gpd.read_file(shp_dir / "adm0.shp.zip")
ner_shp_adm1 = gpd.read_file(shp_dir / "adm1.shp.zip")
ner_shp_adm2 = gpd.read_file(shp_dir / "adm2.shp.zip")

ner_spi = pd.read_csv(data_dir / "SPIdatafile.csv")

# %%
ner_shp_adm0.total_bounds
# Out:
# array([ 0.16625  , 11.69697  , 15.99564  , 23.5331862])

# %%
ner_spi[(ner_spi["Time"] == "Jan-Feb 1981") & (ner_spi["Latitude"] == "11.025N")]
# Out:
#                 Time    Longitude Latitude  Standardized Precipitation Index  \
# 0       Jan-Feb 1981   0.0249939E  11.025N                               NaN
# 500     Jan-Feb 1981  0.07499389E  11.025N                               NaN
# 1000    Jan-Feb 1981   0.1249939E  11.025N                               NaN
# 1500    Jan-Feb 1981   0.1749939E  11.025N                               NaN
# 2000    Jan-Feb 1981   0.2249939E  11.025N                               NaN
# ...              ...          ...      ...                               ...
# 157500  Jan-Feb 1981    15.77499E  11.025N                               NaN
# 158000  Jan-Feb 1981    15.82499E  11.025N                               NaN
# 158500  Jan-Feb 1981    15.87499E  11.025N                               NaN
# 159000  Jan-Feb 1981    15.92499E  11.025N                               NaN
# 159500  Jan-Feb 1981    15.97499E  11.025N                               NaN
#
#                Lon     Lat
# ...

# %% [markdown]
# Point values could be converted to raster values.
# This is done where all touched cells are used.
# However, if using centroid in region, there is no need to.

# %%
len(ner_spi["Latitude"].unique())
len(ner_spi["Longitude"].unique())
# Out:
# 321

# %%
ner_spi["Lon"] = [str[:-1] for str in ner_spi["Longitude"]]
ner_spi["Lat"] = [str[:-1] for str in ner_spi["Latitude"]]

# %%
ner_spi
# Out:
#                   Time                                          Longitude  \
# 0         Jan-Feb 1981                                         0.0249939E
# 1         Feb-Mar 1981                                         0.0249939E
# 2         Mar-Apr 1981                                         0.0249939E
# 3         Apr-May 1981                                         0.0249939E
# 4         May-Jun 1981                                         0.0249939E
# ...                ...                                                ...
# 24089914  Jul-Aug 2015                                          8.974992E
# 24089915  Aug-Sep 2015                                          8.974992E
# 24089916  Sep-Oct 2015                                          8.974992E
# 24089917  Oct-Nov 2015                                          8.974992E
# 24089918  Nov-Dec 2015  Insufficient memory to allocate Fortran RTL me...
#
#                               Latitude  Standardized Precipitation Index  \
# ...

# %%
phl_rwi_gdf = gpd.GeoDataFrame(
    phl_rwi, geometry=gpd.points_from_xy(phl_rwi.longitude, phl_rwi.latitude)
)
